# %% [markdown]
# # <span style="font-family:Courier New; color:#CCCCCC">**Catalan Word2Vec**</span>

# %% [markdown]
# ## <span style="font-family:Courier New; color:#336666">**Load Data and Imports**</span>

# %%
from gensim.utils import simple_preprocess
from typing import Tuple, List, Optional
from gensim.corpora import Dictionary
from datasets import load_dataset # type: ignore
from scipy.stats import pearsonr
import tensorflow as tf
import fasttext # type: ignore
import pandas as pd
import numpy as np
import string
import re
import os

# Load the dataset
dataset = load_dataset("projecte-aina/catalan_general_crawling", split = 'train', trust_remote_code=True)
# Extract text data from the dataset
docs = dataset['text']

# %% [markdown]
# ## <span style="font-family:Courier New; color:#336666">**Basic Preprocessing**</span>

# %%
# Preprocess the sentences
def preprocess(s):

    # Convert to lowercase
    s = s.lower()
    # Replace apostrophes with a space to split words connected by apostrophes
    s = re.sub(r"'", " ", s)
    # Replace hyphens with underscores
    s = re.sub(r"[-]", "_", s) 
    # Remove punctuation
    s =  re.sub(r'[{}]+'.format(re.escape(string.punctuation.replace('_', ''))), '', s)
    #Normalize spaces to 1
    s = re.sub(" +", " ", s.strip())
    # Replace pure number tokens with <num>
    s =  re.sub(r'\b\d+\b', '<num>', s)
    
    return s

# %%
# Save the text data to a text file
with open('data/input_1.txt', 'w', encoding='utf-8') as f:
    for doc in docs:
        f.write("%s\n" % preprocess(doc))

# %%
#Fetch different size data files
def read_and_write_partial_file(in_file, out_file, size):
    with open(in_file, 'rb') as inf:
        with open(out_file, 'wb') as outf:
            partial_data = inf.read(size)
            outf.write(partial_data)

whole_data_size = os.path.getsize('data/input_1.txt')         
MB = 1024*1024 #bytes
sizes = [100*MB, 500*MB, 1024*MB]
for size in sizes:
    out_file = f'data/input_{round(size/whole_data_size, 2)}.txt'
    read_and_write_partial_file('data/input_1.txt', out_file, size)

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Train Models**</span>

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Skip-gram**</span>

# %%
#First model -> 100MB
model_100 = fasttext.train_unsupervised(
    'data/input_0.04.txt', model='skipgram', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 0, maxn = 0, #skip-gram
    neg = 4, 
    t = 1e-5, #prevent stopwords from impacting training time
)
model_100.save_model("dist_models/skip-gram_100MB.bin")

# %%
#Second model -> 500MB
model_500 = fasttext.train_unsupervised(
    'data/input_0.2.txt', model='skipgram', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 0, maxn = 0, #skip-gram
    neg = 4, 
    t = 1e-5, #prevent stopwords from impacting training time
)
model_500.save_model("dist_models/skip-gram_500MB.bin")

# %%
#Third model -> 1GB
model_1GB = fasttext.train_unsupervised(
    'data/input_0.4.txt', model='skipgram', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 0, maxn = 0, #skip-gram
    neg = 4, 
    t = 1e-6, #prevent stopwords from impacting training time
)
model_1GB.save_model("dist_models/skip-gram_1GB.bin")

# %%
#Fourth model -> whole dataset
model_whole = fasttext.train_unsupervised(
    'data/input_1.txt', model='skipgram', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 0, maxn = 0, #skip-gram
    neg = 4, 
    t = 1e-7, #prevent stopwords from impacting training time
)
model_whole.save_model("dist_models/skip-gram_whole.bin")

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**CBOW**</span>

# %%
model_cbow = fasttext.train_unsupervised(
    'data/input_1.txt', model='cbow', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 0, maxn = 0, #cbow
    neg = 4, 
    t = 1e-7, #prevent stopwords from impacting training time
)
model_cbow.save_model("dist_models/cbow_whole.bin")

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**FastText**</span>

# %%
model_fasttext = fasttext.train_unsupervised(
    'data/input_1.txt', model='skipgram', 
    dim = 100, 
    ws = 5, 
    minCount = 5, 
    minn = 3, maxn = 6, #fasttext
    neg = 5, 
    t = 1e-7, #prevent stopwords from impacting training time
)   
model_fasttext.save_model("dist_models/fasttext_whole.bin")

# %% [markdown]
# ## <span style="font-family:Courier New; color:#336666">**Intrinsic Evaluation**</span>

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Skip-gram**</span>

# %%
model_100 = fasttext.load_model('dist_models/skip-gram_100MB.bin')
model_500 = fasttext.load_model('dist_models/skip-gram_500MB.bin')
model_1GB = fasttext.load_model('dist_models/skip-gram_1GB.bin')
model_whole = fasttext.load_model('dist_models/skip-gram_whole.bin')
models = [model_100, model_500, model_1GB, model_whole]

# %%
def cosine_similarity(vec1, vec2):
    dot_product = sum(a * b for a, b in zip(vec1, vec2))
    magnitude1 = sum(a ** 2 for a in vec1) ** 0.5
    magnitude2 = sum(b ** 2 for b in vec2) ** 0.5
    return dot_product / (magnitude1 * magnitude2)

index = ['100MB', '500MB', '1GB', 'whole']
columns = [('home', 'dona'), ('blau', 'vermell'), ('dormir', 'llit'), ('feliç', 'felicitat')]

sim_df = pd.DataFrame()
for i, model in enumerate(models):
    for w1, w2 in columns:
        vec1 = model[w1]
        vec2 = model[w2]
        sim_df.loc[index[i], f'({w1}, {w2})'] = cosine_similarity(vec1, vec2)
sim_df
# Out:
#        (home, dona)  (blau, vermell)  (dormir, llit)  (feliç, felicitat)
# 100MB      0.452221         0.672529        0.597621            0.495984
# 500MB      0.556385         0.714803        0.706539            0.532513
# 1GB        0.649668         0.811982        0.743771            0.614395
# whole      0.641329         0.835277        0.843755            0.729914

# %% [markdown]
# <span style="font-family:Courier New">As we can see, the more training data is used to train the models, the better they capture similarity between words. </span>

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Skip-gram, CBOW or FastText?**</span>

# %%
skipgram = fasttext.load_model('dist_models/skip-gram_whole.bin')
cbow = fasttext.load_model('dist_models/cbow_whole.bin')
fasttext = fasttext.load_model('dist_models/fasttext_whole.bin')
models = [skipgram, cbow, fasttext]

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Distància**</span>

# %%
index = ['skip-gram', 'cbow', 'fasttext']
columns = [('opípar', 'majestuós'), ('blau', 'vermell'), ('dormir', 'llit'), ('feliç', 'felicitat'), ('treball', 'plàtan')]

dist_df = pd.DataFrame()
for i, model in enumerate(models):
    for w1, w2 in columns:
        vec1 = model[w1]
        vec2 = model[w2]
        dist_df.loc[index[i], f'({w1}, {w2})'] = cosine_similarity(vec1, vec2)
dist_df
# Out:
#            (opípar, majestuós)  (blau, vermell)  (dormir, llit)  \
# skip-gram             0.764406         0.835277        0.843755
# cbow                  0.721126         0.941667        0.925060
# fasttext              0.515112         0.703621        0.609546
#
#            (feliç, felicitat)  (treball, plàtan)
# skip-gram            0.729914           0.177631
# cbow                 0.838973           0.055132
# fasttext             0.665305           0.224750

# %% [markdown]
# <span style="font-family:Courier New">At this point, CBOW seems to be the best embeddding model, since its coisine similarity corresponds well with actual words' semantics, in both senses: see that `treball` and `platan` coisine value is very low, but `blau` and `vermell` very high. </span>

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Similitud**</span>

# %%
index = ['skip-gram', 'cbow', 'fasttext']

sim_df = pd.DataFrame(columns=list(range(1,6)))
for i, model in enumerate(models):
    nn = model.get_nearest_neighbors('croqueta', k = 5)
    sim_df.loc[index[i]] = [w for _,w in nn]
sim_df
# Out:
#                    1          2          3           4          5
# skip-gram  salmorejo   gaspatxo     caneló  verduretes  escalivat
# cbow           bitxo  carbonara       flam       melós     xarrup
# fasttext     croquet   broqueta  croquetes     coqueta  bajoqueta

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Analogia**</span>

# %%
index = ['skip-gram', 'cbow', 'fasttext']

sim_df = pd.DataFrame(columns=list(range(1,6)))
for i, model in enumerate(models):
    nn = model.get_analogies('fill', 'filla', 'pare', k = 5)
    sim_df.loc[index[i]] = [w for _,w in nn]
sim_df
# Out:
#                1          2        3          4      5
# skip-gram   amic      germà     cosí   sacerdot   tiet
# cbow        amic      amiga  germana       mare  germà
# fasttext   filll  fill_pare    filló  pare_mare  espòs

# %% [markdown]
# ## <span style="font-family:Courier New; color:#336666">**Extrinsic Evaluation**</span>

# %% [markdown]
# <span style="font-family:Courier New">In this section, we are going to test the embeddings in a specific task: similarity regression model.</span>

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Data Preparation**</span>

# %%
dataset = load_dataset("projecte-aina/sts-ca", trust_remote_code=True)

input_pairs = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["train"].to_list()]
input_pairs_val = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["validation"].to_list()]
input_pairs_test = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["test"].to_list()]

all_input_pairs = input_pairs + input_pairs_val + input_pairs_test

# Preprocesamiento de las oraciones y creación del diccionario
sentences_1_preproc = [simple_preprocess(sentence_1) for sentence_1, _, _ in all_input_pairs]
sentences_2_preproc = [simple_preprocess(sentence_2) for _, sentence_2, _ in all_input_pairs]
sentence_pairs = list(zip(sentences_1_preproc, sentences_2_preproc))

# Versión mapeada de palabras a ids para poder entrenar el modelo
sentences_pairs_flattened = sentences_1_preproc + sentences_2_preproc
diccionario = Dictionary(sentences_pairs_flattened)

# %%
def map_word_embeddings(
        sentence: str,
        fixed_dictionary: Dictionary,
        sequence_len: int = 96
) -> np.ndarray:
    """
    Map to word-embedding indices
    :param sentence:
    :param sequence_len:
    :param fixed_dictionary:
    :return:
    """
    sentence_preproc = simple_preprocess(sentence)[:sequence_len]
    _vectors = np.zeros(sequence_len, dtype=np.int32)
    index = 0
    for word in sentence_preproc:
        if word in fixed_dictionary.token2id:
            # Sumo 1 porque el valor 0 está reservado a padding
            _vectors[index] = fixed_dictionary.token2id[word] + 1
            index += 1    
    return _vectors

def map_pairs(
    sentence_pairs: List[Tuple[str, str, float]],
    fixed_dictionary: Dictionary,
    sequence_len: int = 96
) -> List[Tuple[Tuple[np.ndarray, np.ndarray], float]]:
    
    # Mapeo de los pares de oraciones a pares de vectores
    pares_vectores = []
    for (sentence_1, sentence_2, similitud) in sentence_pairs:
        vector1 = map_word_embeddings(sentence_1, fixed_dictionary, sequence_len)
        vector2 = map_word_embeddings(sentence_2, fixed_dictionary, sequence_len)
        # Añadir a la lista
        pares_vectores.append(((vector1, vector2), similitud))
    return pares_vectores

mapped_train = map_pairs(input_pairs, fixed_dictionary = diccionario)
mapped_val = map_pairs(input_pairs_val, fixed_dictionary = diccionario)
mapped_test = map_pairs(input_pairs_test, fixed_dictionary = diccionario)

# %%
# Obtener x_train e y_train
def pair_list_to_x_y(pair_list: List[Tuple[Tuple[np.ndarray, np.ndarray], int]]) -> Tuple[Tuple[np.ndarray, np.ndarray], np.ndarray]:
    _x, _y = zip(*pair_list)
    _x_1, _x_2 = zip(*_x)
    return (np.row_stack(_x_1), np.row_stack(_x_2)), np.array(_y)

# Obtener las listas de train y test
x_train, y_train = pair_list_to_x_y(mapped_train)
x_val, y_val = pair_list_to_x_y(mapped_val)

# Preparar los conjuntos de datos de entrenamiento y validación
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=len(x_train)).batch(64)

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Build Models and Train**</span>

# %%
#Regression similarity model template
def model(
    input_length: int = 96,
    dictionary_size: int = 1000,
    embedding_size: int = 16,
    pretrained_weights: Optional[np.ndarray] = None,
    learning_rate: float = 1e-3,
) -> tf.keras.Model:
    # Input layers
    input_1 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)
    input_2 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)

    # Embedding layer
    if pretrained_weights is None:
        embedding = tf.keras.layers.Embedding(
            dictionary_size, embedding_size, input_length=input_length, mask_zero=True
        )
    else:
        dictionary_size = pretrained_weights.shape[0]
        embedding_size = pretrained_weights.shape[1]
        initializer = tf.keras.initializers.Constant(pretrained_weights)
        embedding = tf.keras.layers.Embedding(
            dictionary_size,
            embedding_size,
            input_length=input_length,
            mask_zero=True,
            embeddings_initializer=initializer,
            trainable=False,
        )

    # Apply embedding to input sequences
    embedded_1 = embedding(input_1)
    embedded_2 = embedding(input_2)
    # Global average pooling
    _input_mask_1 = tf.keras.layers.Lambda(lambda x: tf.not_equal(x, 0))(input_1)
    _input_mask_2 = tf.keras.layers.Lambda(lambda x: tf.not_equal(x, 0))(input_2)
    pooled_1 = tf.keras.layers.GlobalAveragePooling1D()(embedded_1, mask=_input_mask_1)
    pooled_2 = tf.keras.layers.GlobalAveragePooling1D()(embedded_2, mask=_input_mask_2)

    # Compute the cosine distance using a Lambda layer
    def normalized_product(x):
        x1, x2 = x
        x1_normalized = tf.keras.backend.l2_normalize(x1, axis=1)
        x2_normalized = tf.keras.backend.l2_normalize(x2, axis=1)
        return x1_normalized * x2_normalized
    
    output = tf.keras.layers.Lambda(normalized_product)([pooled_1, pooled_2])
    output = tf.keras.layers.Dense(64, activation="relu")(output)
    output = tf.keras.layers.Dropout(0.2)(output)
    output = tf.keras.layers.Dense(128, activation="relu")(output)
    output = tf.keras.layers.Dropout(0.2)(output)
    output = tf.keras.layers.Dense(1)(output)

    # Define the model
    model = tf.keras.Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model
    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate))

    return model

# %%
#Map trained embedddings with input data ids

embedding_size = 100
#skipgram
_pretrained_weights_skipgram = np.zeros(
            (len(diccionario.token2id) + 1, embedding_size),  dtype=np.float32)
for token, _id in diccionario.token2id.items():
    if token in skipgram:
        _pretrained_weights_skipgram[_id + 1] = skipgram[token]

#cbow
_pretrained_weights_cbow = np.zeros(
            (len(diccionario.token2id) + 1, embedding_size),  dtype=np.float32)
for token, _id in diccionario.token2id.items():
    if token in cbow:
        _pretrained_weights_cbow[_id + 1] = cbow[token]

#fasttext
_pretrained_weights_fasttext = np.zeros(
            (len(diccionario.token2id) + 1, embedding_size),  dtype=np.float32)
for token, _id in diccionario.token2id.items():
    if token in fasttext:
        _pretrained_weights_fasttext[_id + 1] = fasttext[token]

# %%
# Build and compile the models
model_skipgram = model(pretrained_weights=_pretrained_weights_skipgram)
model_cbow = model(pretrained_weights=_pretrained_weights_cbow)
model_fasttext = model(pretrained_weights=_pretrained_weights_fasttext)
model_skipgram.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 96, 100)   │  1,312,600 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 96)        │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 96)        │          0 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 100)       │          0 │ embedding_1[0][0… │
# │ (GlobalAveragePool… │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 100)       │          0 │ embedding_1[1][0… │
# │ (GlobalAveragePool… │                   │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 100)       │          0 │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │      6,464 │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │      8,320 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │        129 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,327,513 (5.06 MB)
#  Trainable params: 14,913 (58.25 KB)
#  Non-trainable params: 1,312,600 (5.01 MB)

# %%
# Train the models
model_skipgram.fit(train_dataset, epochs=128, steps_per_epoch=100, validation_data=val_dataset)
model_cbow.fit(train_dataset, epochs=128, steps_per_epoch=100, validation_data=val_dataset)
model_fasttext.fit(train_dataset, epochs=128, steps_per_epoch=100, validation_data=val_dataset)
models = [model_skipgram, model_cbow, model_fasttext]
# Out:
# Epoch 1/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.7681 - val_loss: 2.4657
# Epoch 2/128
#  17/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7355
# c:\Users\jerez\.pyenv\pyenv-win\versions\3.10.10\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1801 - val_loss: 0.7164
# Epoch 3/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7710 - val_loss: 0.7110
# Epoch 4/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7460 - val_loss: 0.7075
# Epoch 5/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7480 - val_loss: 0.7047
# Epoch 6/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7418 - val_loss: 0.7021
# Epoch 7/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7501 - val_loss: 0.6991
# Epoch 8/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7332 - val_loss: 0.6964
# Epoch 9/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7250 - val_loss: 0.6941
# Epoch 10/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7215 - val_loss: 0.6919
# Epoch 11/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7098 - val_loss: 0.6904
# Epoch 12/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7138 - val_loss: 0.6887
# Epoch 13/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7013 - val_loss: 0.6883
# Epoch 14/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7093 - val_loss: 0.6878
# Epoch 15/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7107 - val_loss: 0.6858
# Epoch 16/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7108 - val_loss: 0.6833
# Epoch 17/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7002 - val_loss: 0.6818
# Epoch 18/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6985 - val_loss: 0.6836
# Epoch 19/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7084 - val_loss: 0.6804
# Epoch 20/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6898 - val_loss: 0.6799
# Epoch 21/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6868 - val_loss: 0.6768
# Epoch 22/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6756 - val_loss: 0.6769
# Epoch 23/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6714 - val_loss: 0.6760
# Epoch 24/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6805 - val_loss: 0.6773
# Epoch 25/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6746 - val_loss: 0.6750
# Epoch 26/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6695 - val_loss: 0.6742
# Epoch 27/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6614 - val_loss: 0.6713
# Epoch 28/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6646 - val_loss: 0.6712
# Epoch 29/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6386 - val_loss: 0.6705
# Epoch 30/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6574 - val_loss: 0.6690
# Epoch 31/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6548 - val_loss: 0.6709
# Epoch 32/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6566 - val_loss: 0.6674
# Epoch 33/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6645 - val_loss: 0.6657
# Epoch 34/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6438 - val_loss: 0.6668
# Epoch 35/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6518 - val_loss: 0.6653
# Epoch 36/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6358 - val_loss: 0.6683
# Epoch 37/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6480 - val_loss: 0.6643
# Epoch 38/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6375 - val_loss: 0.6652
# Epoch 39/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6346 - val_loss: 0.6608
# Epoch 40/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6405 - val_loss: 0.6592
# Epoch 41/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6249 - val_loss: 0.6616
# Epoch 42/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6241 - val_loss: 0.6580
# Epoch 43/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6323 - val_loss: 0.6602
# Epoch 44/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6230 - val_loss: 0.6548
# Epoch 45/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6308 - val_loss: 0.6520
# Epoch 46/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6358 - val_loss: 0.6524
# Epoch 47/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6209 - val_loss: 0.6564
# Epoch 48/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6285 - val_loss: 0.6510
# Epoch 49/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6126 - val_loss: 0.6494
# Epoch 50/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6156 - val_loss: 0.6500
# Epoch 51/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6229 - val_loss: 0.6473
# Epoch 52/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6148 - val_loss: 0.6475
# Epoch 53/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6165 - val_loss: 0.6461
# Epoch 54/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6097 - val_loss: 0.6442
# Epoch 55/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6071 - val_loss: 0.6430
# Epoch 56/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6096 - val_loss: 0.6391
# Epoch 57/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6149 - val_loss: 0.6417
# Epoch 58/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6058 - val_loss: 0.6439
# Epoch 59/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5970 - val_loss: 0.6406
# Epoch 60/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5989 - val_loss: 0.6382
# Epoch 61/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5942 - val_loss: 0.6370
# Epoch 62/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5965 - val_loss: 0.6347
# Epoch 63/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5937 - val_loss: 0.6346
# Epoch 64/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5874 - val_loss: 0.6391
# Epoch 65/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5853 - val_loss: 0.6365
# Epoch 66/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5851 - val_loss: 0.6356
# Epoch 67/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5747 - val_loss: 0.6327
# Epoch 68/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5838 - val_loss: 0.6275
# Epoch 69/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5752 - val_loss: 0.6331
# Epoch 70/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5687 - val_loss: 0.6300
# Epoch 71/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5709 - val_loss: 0.6300
# Epoch 72/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5564 - val_loss: 0.6304
# Epoch 73/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5708 - val_loss: 0.6299
# Epoch 74/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5499 - val_loss: 0.6242
# Epoch 75/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5488 - val_loss: 0.6264
# Epoch 76/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5550 - val_loss: 0.6275
# Epoch 77/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5567 - val_loss: 0.6263
# Epoch 78/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5567 - val_loss: 0.6266
# Epoch 79/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5528 - val_loss: 0.6238
# Epoch 80/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5481 - val_loss: 0.6249
# Epoch 81/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5514 - val_loss: 0.6274
# Epoch 82/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5442 - val_loss: 0.6328
# Epoch 83/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5385 - val_loss: 0.6254
# Epoch 84/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5376 - val_loss: 0.6200
# Epoch 85/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5393 - val_loss: 0.6207
# Epoch 86/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5329 - val_loss: 0.6246
# Epoch 87/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5382 - val_loss: 0.6152
# Epoch 88/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5168 - val_loss: 0.6231
# Epoch 89/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5257 - val_loss: 0.6196
# Epoch 90/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5208 - val_loss: 0.6174
# Epoch 91/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5195 - val_loss: 0.6180
# Epoch 92/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5321 - val_loss: 0.6293
# Epoch 93/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5206 - val_loss: 0.6127
# Epoch 94/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5088 - val_loss: 0.6174
# Epoch 95/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5086 - val_loss: 0.6202
# Epoch 96/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4981 - val_loss: 0.6162
# Epoch 97/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5063 - val_loss: 0.6129
# Epoch 98/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5076 - val_loss: 0.6419
# Epoch 99/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4811 - val_loss: 0.6141
# Epoch 100/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5041 - val_loss: 0.6167
# Epoch 101/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4979 - val_loss: 0.6308
# Epoch 102/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4878 - val_loss: 0.6257
# Epoch 103/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4889 - val_loss: 0.6323
# Epoch 104/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4914 - val_loss: 0.6168
# Epoch 105/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4716 - val_loss: 0.6080
# Epoch 106/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4941 - val_loss: 0.6114
# Epoch 107/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4797 - val_loss: 0.6194
# Epoch 108/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4774 - val_loss: 0.6029
# Epoch 109/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4810 - val_loss: 0.6228
# Epoch 110/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4719 - val_loss: 0.6113
# Epoch 111/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4831 - val_loss: 0.6095
# Epoch 112/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4759 - val_loss: 0.6185
# Epoch 113/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4666 - val_loss: 0.6154
# Epoch 114/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4687 - val_loss: 0.6170
# Epoch 115/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4508 - val_loss: 0.6127
# Epoch 116/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4598 - val_loss: 0.6056
# Epoch 117/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4634 - val_loss: 0.6181
# Epoch 118/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4562 - val_loss: 0.6215
# Epoch 119/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4368 - val_loss: 0.6089
# Epoch 120/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4573 - val_loss: 0.6079
# Epoch 121/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4451 - val_loss: 0.6186
# Epoch 122/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4606 - val_loss: 0.6014
# Epoch 123/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4388 - val_loss: 0.5998
# Epoch 124/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4521 - val_loss: 0.6212
# Epoch 125/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4501 - val_loss: 0.6236
# Epoch 126/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4367 - val_loss: 0.6079
# Epoch 127/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4337 - val_loss: 0.5994
# Epoch 128/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4400 - val_loss: 0.6119
# Epoch 1/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5.8225 - val_loss: 2.4839
# Epoch 2/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1926 - val_loss: 0.7221
# Epoch 3/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7734 - val_loss: 0.7152
# Epoch 4/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7513 - val_loss: 0.7092
# Epoch 5/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7417 - val_loss: 0.7038
# Epoch 6/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7288 - val_loss: 0.6999
# Epoch 7/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7449 - val_loss: 0.6950
# Epoch 8/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7164 - val_loss: 0.6926
# Epoch 9/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7213 - val_loss: 0.6897
# Epoch 10/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7227 - val_loss: 0.6883
# Epoch 11/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6914 - val_loss: 0.6878
# Epoch 12/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7023 - val_loss: 0.6858
# Epoch 13/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6874 - val_loss: 0.6845
# Epoch 14/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6870 - val_loss: 0.6817
# Epoch 15/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7018 - val_loss: 0.6810
# Epoch 16/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6916 - val_loss: 0.6836
# Epoch 17/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6901 - val_loss: 0.6796
# Epoch 18/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6763 - val_loss: 0.6785
# Epoch 19/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6859 - val_loss: 0.6781
# Epoch 20/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6784 - val_loss: 0.6757
# Epoch 21/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6812 - val_loss: 0.6765
# Epoch 22/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6809 - val_loss: 0.6748
# Epoch 23/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6816 - val_loss: 0.6788
# Epoch 24/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6719 - val_loss: 0.6723
# Epoch 25/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6645 - val_loss: 0.6732
# Epoch 26/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6529 - val_loss: 0.6714
# Epoch 27/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6608 - val_loss: 0.6694
# Epoch 28/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6588 - val_loss: 0.6663
# Epoch 29/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6649 - val_loss: 0.6714
# Epoch 30/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6608 - val_loss: 0.6644
# Epoch 31/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6590 - val_loss: 0.6662
# Epoch 32/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6482 - val_loss: 0.6644
# Epoch 33/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6474 - val_loss: 0.6667
# Epoch 34/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6533 - val_loss: 0.6635
# Epoch 35/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6573 - val_loss: 0.6620
# Epoch 36/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6520 - val_loss: 0.6605
# Epoch 37/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6411 - val_loss: 0.6638
# Epoch 38/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6340 - val_loss: 0.6605
# Epoch 39/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6419 - val_loss: 0.6680
# Epoch 40/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6165 - val_loss: 0.6576
# Epoch 41/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6244 - val_loss: 0.6571
# Epoch 42/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6389 - val_loss: 0.6575
# Epoch 43/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6269 - val_loss: 0.6579
# Epoch 44/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6284 - val_loss: 0.6545
# Epoch 45/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6154 - val_loss: 0.6538
# Epoch 46/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6115 - val_loss: 0.6549
# Epoch 47/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6232 - val_loss: 0.6508
# Epoch 48/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6199 - val_loss: 0.6501
# Epoch 49/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6050 - val_loss: 0.6523
# Epoch 50/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6184 - val_loss: 0.6544
# Epoch 51/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6189 - val_loss: 0.6504
# Epoch 52/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6135 - val_loss: 0.6541
# Epoch 53/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6172 - val_loss: 0.6507
# Epoch 54/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6059 - val_loss: 0.6511
# Epoch 55/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5977 - val_loss: 0.6473
# Epoch 56/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5976 - val_loss: 0.6473
# Epoch 57/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5900 - val_loss: 0.6475
# Epoch 58/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5983 - val_loss: 0.6438
# Epoch 59/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6009 - val_loss: 0.6474
# Epoch 60/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5879 - val_loss: 0.6482
# Epoch 61/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5938 - val_loss: 0.6461
# Epoch 62/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5755 - val_loss: 0.6456
# Epoch 63/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5851 - val_loss: 0.6441
# Epoch 64/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5917 - val_loss: 0.6485
# Epoch 65/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5805 - val_loss: 0.6401
# Epoch 66/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5861 - val_loss: 0.6491
# Epoch 67/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5810 - val_loss: 0.6448
# Epoch 68/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5801 - val_loss: 0.6444
# Epoch 69/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5831 - val_loss: 0.6459
# Epoch 70/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5703 - val_loss: 0.6433
# Epoch 71/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5811 - val_loss: 0.6427
# Epoch 72/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5747 - val_loss: 0.6404
# Epoch 73/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5662 - val_loss: 0.6430
# Epoch 74/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5657 - val_loss: 0.6437
# Epoch 75/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5573 - val_loss: 0.6447
# Epoch 76/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5724 - val_loss: 0.6388
# Epoch 77/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5745 - val_loss: 0.6390
# Epoch 78/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5561 - val_loss: 0.6435
# Epoch 79/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5527 - val_loss: 0.6419
# Epoch 80/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5605 - val_loss: 0.6383
# Epoch 81/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5469 - val_loss: 0.6386
# Epoch 82/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5448 - val_loss: 0.6399
# Epoch 83/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5468 - val_loss: 0.6338
# Epoch 84/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5411 - val_loss: 0.6416
# Epoch 85/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5391 - val_loss: 0.6405
# Epoch 86/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5476 - val_loss: 0.6389
# Epoch 87/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5399 - val_loss: 0.6439
# Epoch 88/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5330 - val_loss: 0.6413
# Epoch 89/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5308 - val_loss: 0.6426
# Epoch 90/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5438 - val_loss: 0.6407
# Epoch 91/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5297 - val_loss: 0.6429
# Epoch 92/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5251 - val_loss: 0.6444
# Epoch 93/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5267 - val_loss: 0.6447
# Epoch 94/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5346 - val_loss: 0.6469
# Epoch 95/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5421 - val_loss: 0.6426
# Epoch 96/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5356 - val_loss: 0.6502
# Epoch 97/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5205 - val_loss: 0.6405
# Epoch 98/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5265 - val_loss: 0.6469
# Epoch 99/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5267 - val_loss: 0.6404
# Epoch 100/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5267 - val_loss: 0.6376
# Epoch 101/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5093 - val_loss: 0.6364
# Epoch 102/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5203 - val_loss: 0.6371
# Epoch 103/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5206 - val_loss: 0.6426
# Epoch 104/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5214 - val_loss: 0.6450
# Epoch 105/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5033 - val_loss: 0.6481
# Epoch 106/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5172 - val_loss: 0.6474
# Epoch 107/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5131 - val_loss: 0.6530
# Epoch 108/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5106 - val_loss: 0.6553
# Epoch 109/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5056 - val_loss: 0.6456
# Epoch 110/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5029 - val_loss: 0.6468
# Epoch 111/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5006 - val_loss: 0.6435
# Epoch 112/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5011 - val_loss: 0.6406
# Epoch 113/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5015 - val_loss: 0.6393
# Epoch 114/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4862 - val_loss: 0.6418
# Epoch 115/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4922 - val_loss: 0.6470
# Epoch 116/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4928 - val_loss: 0.6490
# Epoch 117/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4805 - val_loss: 0.6487
# Epoch 118/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4923 - val_loss: 0.6472
# Epoch 119/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4917 - val_loss: 0.6507
# Epoch 120/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4763 - val_loss: 0.6528
# Epoch 121/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4782 - val_loss: 0.6573
# Epoch 122/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4723 - val_loss: 0.6560
# Epoch 123/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4707 - val_loss: 0.6404
# Epoch 124/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4745 - val_loss: 0.6533
# Epoch 125/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4920 - val_loss: 0.6433
# Epoch 126/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4716 - val_loss: 0.6439
# Epoch 127/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4840 - val_loss: 0.6537
# Epoch 128/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4748 - val_loss: 0.6464
# Epoch 1/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 5.7658 - val_loss: 2.4870
# Epoch 2/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1990 - val_loss: 0.7121
# Epoch 3/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7632 - val_loss: 0.7070
# Epoch 4/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7436 - val_loss: 0.7065
# Epoch 5/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7381 - val_loss: 0.7021
# Epoch 6/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7252 - val_loss: 0.6996
# Epoch 7/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7129 - val_loss: 0.6981
# Epoch 8/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7185 - val_loss: 0.6939
# Epoch 9/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7277 - val_loss: 0.6909
# Epoch 10/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7067 - val_loss: 0.6896
# Epoch 11/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6959 - val_loss: 0.6868
# Epoch 12/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7219 - val_loss: 0.6830
# Epoch 13/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7096 - val_loss: 0.6809
# Epoch 14/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7024 - val_loss: 0.6845
# Epoch 15/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6792 - val_loss: 0.6765
# Epoch 16/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6837 - val_loss: 0.6747
# Epoch 17/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6719 - val_loss: 0.6762
# Epoch 18/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6970 - val_loss: 0.6716
# Epoch 19/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6698 - val_loss: 0.6753
# Epoch 20/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6739 - val_loss: 0.6724
# Epoch 21/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6597 - val_loss: 0.6673
# Epoch 22/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6597 - val_loss: 0.6673
# Epoch 23/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6703 - val_loss: 0.6660
# Epoch 24/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6437 - val_loss: 0.6649
# Epoch 25/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6545 - val_loss: 0.6649
# Epoch 26/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6614 - val_loss: 0.6609
# Epoch 27/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6427 - val_loss: 0.6602
# Epoch 28/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6398 - val_loss: 0.6593
# Epoch 29/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6443 - val_loss: 0.6571
# Epoch 30/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6562 - val_loss: 0.6576
# Epoch 31/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6469 - val_loss: 0.6555
# Epoch 32/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6263 - val_loss: 0.6573
# Epoch 33/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6407 - val_loss: 0.6506
# Epoch 34/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6334 - val_loss: 0.6520
# Epoch 35/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6356 - val_loss: 0.6568
# Epoch 36/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.6305 - val_loss: 0.6472
# Epoch 37/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6060 - val_loss: 0.6462
# Epoch 38/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6202 - val_loss: 0.6402
# Epoch 39/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.6233 - val_loss: 0.6396
# Epoch 40/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6112 - val_loss: 0.6403
# Epoch 41/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6010 - val_loss: 0.6445
# Epoch 42/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6177 - val_loss: 0.6354
# Epoch 43/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6176 - val_loss: 0.6368
# Epoch 44/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 0.6134 - val_loss: 0.6306
# Epoch 45/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.6035 - val_loss: 0.6378
# Epoch 46/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.6033 - val_loss: 0.6261
# Epoch 47/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.5998 - val_loss: 0.6262
# Epoch 48/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6076 - val_loss: 0.6259
# Epoch 49/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5948 - val_loss: 0.6211
# Epoch 50/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.6032 - val_loss: 0.6170
# Epoch 51/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5998 - val_loss: 0.6185
# Epoch 52/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.5923 - val_loss: 0.6181
# Epoch 53/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5887 - val_loss: 0.6329
# Epoch 54/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5836 - val_loss: 0.6275
# Epoch 55/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5978 - val_loss: 0.6124
# Epoch 56/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5716 - val_loss: 0.6080
# Epoch 57/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5672 - val_loss: 0.6157
# Epoch 58/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5777 - val_loss: 0.6188
# Epoch 59/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5618 - val_loss: 0.6057
# Epoch 60/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5710 - val_loss: 0.6060
# Epoch 61/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5636 - val_loss: 0.6023
# Epoch 62/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5668 - val_loss: 0.6025
# Epoch 63/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.5503 - val_loss: 0.6047
# Epoch 64/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5610 - val_loss: 0.6058
# Epoch 65/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.5636 - val_loss: 0.6005
# Epoch 66/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5612 - val_loss: 0.6050
# Epoch 67/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5529 - val_loss: 0.5959
# Epoch 68/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5441 - val_loss: 0.5937
# Epoch 69/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5516 - val_loss: 0.5902
# Epoch 70/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5466 - val_loss: 0.5932
# Epoch 71/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5494 - val_loss: 0.5968
# Epoch 72/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5486 - val_loss: 0.5943
# Epoch 73/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.5509 - val_loss: 0.5905
# Epoch 74/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5363 - val_loss: 0.5917
# Epoch 75/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5426 - val_loss: 0.5814
# Epoch 76/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.5370 - val_loss: 0.5836
# Epoch 77/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.5390 - val_loss: 0.5818
# Epoch 78/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5424 - val_loss: 0.5930
# Epoch 79/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5299 - val_loss: 0.5855
# Epoch 80/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5210 - val_loss: 0.5830
# Epoch 81/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.5183 - val_loss: 0.5819
# Epoch 82/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.5221 - val_loss: 0.5898
# Epoch 83/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.5221 - val_loss: 0.5762
# Epoch 84/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5299 - val_loss: 0.5917
# Epoch 85/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5106 - val_loss: 0.5867
# Epoch 86/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.4998 - val_loss: 0.5775
# Epoch 87/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5210 - val_loss: 0.5818
# Epoch 88/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5173 - val_loss: 0.5791
# Epoch 89/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.5099 - val_loss: 0.5680
# Epoch 90/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5064 - val_loss: 0.5741
# Epoch 91/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5071 - val_loss: 0.5751
# Epoch 92/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5151 - val_loss: 0.5925
# Epoch 93/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5014 - val_loss: 0.5754
# Epoch 94/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5011 - val_loss: 0.5687
# Epoch 95/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4973 - val_loss: 0.5717
# Epoch 96/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5042 - val_loss: 0.5802
# Epoch 97/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4975 - val_loss: 0.5740
# Epoch 98/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5017 - val_loss: 0.5695
# Epoch 99/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4859 - val_loss: 0.5637
# Epoch 100/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.4837 - val_loss: 0.5708
# Epoch 101/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4923 - val_loss: 0.5679
# Epoch 102/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4855 - val_loss: 0.5661
# Epoch 103/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.4818 - val_loss: 0.5748
# Epoch 104/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4848 - val_loss: 0.5698
# Epoch 105/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.4917 - val_loss: 0.5853
# Epoch 106/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.5006 - val_loss: 0.5716
# Epoch 107/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.4856 - val_loss: 0.5607
# Epoch 108/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4731 - val_loss: 0.5573
# Epoch 109/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.4755 - val_loss: 0.5700
# Epoch 110/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4778 - val_loss: 0.5623
# Epoch 111/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.4710 - val_loss: 0.5683
# Epoch 112/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4720 - val_loss: 0.5716
# Epoch 113/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.4506 - val_loss: 0.5619
# Epoch 114/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4695 - val_loss: 0.5894
# Epoch 115/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4718 - val_loss: 0.5682
# Epoch 116/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 0.4699 - val_loss: 0.5812
# Epoch 117/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4689 - val_loss: 0.5627
# Epoch 118/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4605 - val_loss: 0.5674
# Epoch 119/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4545 - val_loss: 0.5623
# Epoch 120/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4593 - val_loss: 0.5675
# Epoch 121/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4458 - val_loss: 0.5628
# Epoch 122/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4627 - val_loss: 0.5639
# Epoch 123/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4564 - val_loss: 0.5567
# Epoch 124/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4454 - val_loss: 0.5633
# Epoch 125/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.4512 - val_loss: 0.5778
# Epoch 126/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4390 - val_loss: 0.5556
# Epoch 127/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.4403 - val_loss: 0.5570
# Epoch 128/128
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4456 - val_loss: 0.5758

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Evaluation**</span>

# %%
index = ['skipgram', 'cbow', 'fasttext']
results_df = pd.DataFrame(index=index, columns=['cf Pearson (train)', 'cf Pearson (val)', 'cf Pearson (test)'])

x_test, y_test = pair_list_to_x_y(mapped_test)
def compute_pearson(x_, y_, model):
    
    # Get predictions for the model
    y_pred = model.predict(x_)
    # Compute pearson correlation
    correlation, _ = pearsonr(y_pred.flatten(), y_.flatten())
    return correlation

# %%
for i, model in enumerate(index):
    results_df.loc[model, 'cf Pearson (train)'] = compute_pearson(x_train, y_train, models[i])
    results_df.loc[model, 'cf Pearson (val)'] = compute_pearson(x_val, y_val, models[i])
    results_df.loc[model, 'cf Pearson (test)'] = compute_pearson(x_test, y_test, models[i])
results_df
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#          cf Pearson (train) cf Pearson (val) cf Pearson (test)
# skipgram           0.730865         0.423181          0.441365
# cbow               0.637713         0.342591          0.461602
# fasttext           0.740428         0.475816          0.504037
