# %% [markdown]
# # <span style="font-family:Courier New; color:#CCCCCC">**Text Similarity w.Trainable Embeddings**</span>

# %% [markdown]
# ## <span style="font-family:Courier New; color:#336666">**Load Data and Imports**</span>

# %%
from gensim.utils import simple_preprocess
from typing import Tuple, List, Optional
from gensim.corpora import Dictionary
from datasets import load_dataset # type: ignore
from scipy.stats import pearsonr
import tensorflow as tf
import fasttext # type: ignore
import pandas as pd
import numpy as np
import string
import re
import os

dataset = load_dataset("projecte-aina/sts-ca", trust_remote_code=True)

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Data Preparation**</span>

# %%
input_pairs = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["train"].to_list()]
input_pairs_val = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["validation"].to_list()]
input_pairs_test = [(e["sentence1"], e["sentence2"], e["label"], ) for e in dataset["test"].to_list()]

all_input_pairs = input_pairs + input_pairs_val + input_pairs_test

# Preprocesamiento de las oraciones y creación del diccionario
sentences_1_preproc = [simple_preprocess(sentence_1) for sentence_1, _, _ in all_input_pairs]
sentences_2_preproc = [simple_preprocess(sentence_2) for _, sentence_2, _ in all_input_pairs]
sentence_pairs = list(zip(sentences_1_preproc, sentences_2_preproc))

# Versión mapeada de palabras a ids para poder entrenar el modelo
sentences_pairs_flattened = sentences_1_preproc + sentences_2_preproc
diccionario = Dictionary(sentences_pairs_flattened)

# %%
def map_word_embeddings(
        sentence: str,
        fixed_dictionary: Dictionary,
        sequence_len: int = 96
) -> np.ndarray:
    """
    Map to word-embedding indices
    :param sentence:
    :param sequence_len:
    :param fixed_dictionary:
    :return:
    """
    sentence_preproc = simple_preprocess(sentence)[:sequence_len]
    _vectors = np.zeros(sequence_len, dtype=np.int32)
    index = 0
    for word in sentence_preproc:
        if word in fixed_dictionary.token2id:
            # Sumo 1 porque el valor 0 está reservado a padding
            _vectors[index] = fixed_dictionary.token2id[word] + 1
            index += 1    
    return _vectors

def map_pairs(
    sentence_pairs: List[Tuple[str, str, float]],
    fixed_dictionary: Dictionary,
    sequence_len: int = 96
) -> List[Tuple[Tuple[np.ndarray, np.ndarray], float]]:
    
    # Mapeo de los pares de oraciones a pares de vectores
    pares_vectores = []
    for (sentence_1, sentence_2, similitud) in sentence_pairs:
        vector1 = map_word_embeddings(sentence_1, fixed_dictionary, sequence_len)
        vector2 = map_word_embeddings(sentence_2, fixed_dictionary, sequence_len)
        # Añadir a la lista
        pares_vectores.append(((vector1, vector2), similitud))
    return pares_vectores

mapped_train = map_pairs(input_pairs, fixed_dictionary = diccionario)
mapped_val = map_pairs(input_pairs_val, fixed_dictionary = diccionario)
mapped_test = map_pairs(input_pairs_test, fixed_dictionary = diccionario)

# %%
# Obtener x_train e y_train
def pair_list_to_x_y(pair_list: List[Tuple[Tuple[np.ndarray, np.ndarray], int]]) -> Tuple[Tuple[np.ndarray, np.ndarray], np.ndarray]:
    _x, _y = zip(*pair_list)
    _x_1, _x_2 = zip(*_x)
    return (np.row_stack(_x_1), np.row_stack(_x_2)), np.array(_y)

# Obtener las listas de train y test
x_train, y_train = pair_list_to_x_y(mapped_train)
x_val, y_val = pair_list_to_x_y(mapped_val)

# Preparar los conjuntos de datos de entrenamiento y validación
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=len(x_train)).batch(64)

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Train Models**</span>

# %%
#Regression similarity model template
def model(
    input_length: int = 96,
    dictionary_size: int = 1000,
    embedding_size: int = 16,
    pretrained_weights: Optional[np.ndarray] = None,
    learning_rate: float = 1e-3,
    trainable: bool = False,
) -> tf.keras.Model:
    # Input layers
    input_1 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)
    input_2 = tf.keras.Input(shape=(input_length,), dtype=tf.int32)

    # Embedding layer
    if pretrained_weights is None:
        embedding = tf.keras.layers.Embedding(
            dictionary_size, embedding_size, input_length=input_length, mask_zero=True
        )
    else:
        dictionary_size = pretrained_weights.shape[0]
        embedding_size = pretrained_weights.shape[1]
        initializer = tf.keras.initializers.Constant(pretrained_weights)
        embedding = tf.keras.layers.Embedding(
            dictionary_size,
            embedding_size,
            input_length=input_length,
            mask_zero=True,
            embeddings_initializer=initializer,
            trainable=trainable,
        )

    # Apply embedding to input sequences
    embedded_1 = embedding(input_1)
    embedded_2 = embedding(input_2)
    # Global average pooling
    _input_mask_1 = tf.keras.layers.Lambda(lambda x: tf.not_equal(x, 0))(input_1)
    _input_mask_2 = tf.keras.layers.Lambda(lambda x: tf.not_equal(x, 0))(input_2)
    pooled_1 = tf.keras.layers.GlobalAveragePooling1D()(embedded_1, mask=_input_mask_1)
    pooled_2 = tf.keras.layers.GlobalAveragePooling1D()(embedded_2, mask=_input_mask_2)

    # Compute the cosine distance using a Lambda layer
    def normalized_product(x):
        x1, x2 = x
        x1_normalized = tf.keras.backend.l2_normalize(x1, axis=1)
        x2_normalized = tf.keras.backend.l2_normalize(x2, axis=1)
        return x1_normalized * x2_normalized
    
    output = tf.keras.layers.Lambda(normalized_product)([pooled_1, pooled_2])
    output = tf.keras.layers.Dense(64, activation="relu")(output)
    output = tf.keras.layers.Dropout(0.5)(output)
    output = tf.keras.layers.Dense(128, activation="relu")(output)
    output = tf.keras.layers.Dropout(0.25)(output)
    output = tf.keras.layers.Dense(1)(output)

    # Define the model
    model = tf.keras.Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model
    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate))

    return model

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Random Initialized**</span>

# %%
#Add 1 because 0-index is for padding
model_random = model(dictionary_size = len(diccionario) + 1, embedding_size = 16)
model_random.summary()
# Out:
# Model: "functional_75"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_74      │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_75      │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_37        │ (None, 96, 16)    │    210,016 │ input_layer_74[0… │
# │ (Embedding)         │                   │            │ input_layer_75[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_111 (Lambda) │ (None, 96)        │          0 │ input_layer_74[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_112 (Lambda) │ (None, 96)        │          0 │ input_layer_75[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ embedding_37[0][… │
# │ (GlobalAveragePool… │                   │            │ lambda_111[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ embedding_37[1][… │
# │ (GlobalAveragePool… │                   │            │ lambda_112[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_113 (Lambda) │ (None, 16)        │          0 │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_107 (Dense)   │ (None, 64)        │      1,088 │ lambda_113[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_70          │ (None, 64)        │          0 │ dense_107[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_108 (Dense)   │ (None, 128)       │      8,320 │ dropout_70[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_71          │ (None, 128)       │          0 │ dense_108[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_109 (Dense)   │ (None, 1)         │        129 │ dropout_71[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 219,553 (857.63 KB)
#  Trainable params: 219,553 (857.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_random.fit(train_dataset, epochs=128, validation_data=val_dataset)
# Out:
# Epoch 1/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1215 - val_loss: 0.6794
# Epoch 2/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1256 - val_loss: 0.6869
# Epoch 3/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1098 - val_loss: 0.6881
# Epoch 4/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1242 - val_loss: 0.6941
# Epoch 5/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1165 - val_loss: 0.6890
# Epoch 6/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1074 - val_loss: 0.6898
# Epoch 7/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1227 - val_loss: 0.6929
# Epoch 8/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1148 - val_loss: 0.6869
# Epoch 9/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1201 - val_loss: 0.6852
# Epoch 10/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1111 - val_loss: 0.6847
# Epoch 11/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1108 - val_loss: 0.6816
# Epoch 12/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1123 - val_loss: 0.6814
# Epoch 13/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1091 - val_loss: 0.6777
# Epoch 14/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1245 - val_loss: 0.6819
# Epoch 15/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1210 - val_loss: 0.6777
# Epoch 16/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1019 - val_loss: 0.6760
# Epoch 17/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1133 - val_loss: 0.6745
# Epoch 18/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1101 - val_loss: 0.6725
# Epoch 19/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1121 - val_loss: 0.6947
# Epoch 20/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1251 - val_loss: 0.6907
# Epoch 21/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1080 - val_loss: 0.6846
# Epoch 22/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1024 - val_loss: 0.6860
# Epoch 23/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1087 - val_loss: 0.7019
# Epoch 24/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0957 - val_loss: 0.6973
# Epoch 25/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1195 - val_loss: 0.7248
# Epoch 26/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1108 - val_loss: 0.6950
# Epoch 27/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1186 - val_loss: 0.6957
# Epoch 28/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1210 - val_loss: 0.6894
# Epoch 29/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1143 - val_loss: 0.6898
# Epoch 30/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1114 - val_loss: 0.6829
# Epoch 31/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1031 - val_loss: 0.6809
# Epoch 32/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1096 - val_loss: 0.6935
# Epoch 33/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1082 - val_loss: 0.7218
# Epoch 34/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1202 - val_loss: 0.7376
# Epoch 35/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1102 - val_loss: 0.7361
# Epoch 36/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1224 - val_loss: 0.7641
# Epoch 37/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1360 - val_loss: 0.7573
# Epoch 38/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1275 - val_loss: 0.7156
# Epoch 39/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1212 - val_loss: 0.6964
# Epoch 40/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1177 - val_loss: 0.6710
# Epoch 41/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1093 - val_loss: 0.6794
# Epoch 42/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1216 - val_loss: 0.7108
# Epoch 43/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1147 - val_loss: 0.7358
# Epoch 44/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1229 - val_loss: 0.7421
# Epoch 45/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1140 - val_loss: 0.7313
# Epoch 46/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1283 - val_loss: 0.7182
# Epoch 47/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1102 - val_loss: 0.6942
# Epoch 48/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1016 - val_loss: 0.6781
# Epoch 49/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0945 - val_loss: 0.6824
# Epoch 50/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1007 - val_loss: 0.6881
# Epoch 51/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1019 - val_loss: 0.6926
# Epoch 52/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0856 - val_loss: 0.7040
# Epoch 53/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1108 - val_loss: 0.7057
# Epoch 54/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1037 - val_loss: 0.6966
# Epoch 55/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0958 - val_loss: 0.6762
# Epoch 56/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1006 - val_loss: 0.6723
# Epoch 57/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0910 - val_loss: 0.6712
# Epoch 58/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0943 - val_loss: 0.6696
# Epoch 59/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0926 - val_loss: 0.6745
# Epoch 60/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0901 - val_loss: 0.6881
# Epoch 61/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0885 - val_loss: 0.6878
# Epoch 62/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0797 - val_loss: 0.6819
# Epoch 63/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0893 - val_loss: 0.6867
# Epoch 64/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0856 - val_loss: 0.6756
# Epoch 65/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0810 - val_loss: 0.6789
# Epoch 66/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0886 - val_loss: 0.6748
# Epoch 67/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0907 - val_loss: 0.6786
# Epoch 68/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0810 - val_loss: 0.6699
# Epoch 69/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0835 - val_loss: 0.6654
# Epoch 70/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0833 - val_loss: 0.6669
# Epoch 71/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0738 - val_loss: 0.6694
# Epoch 72/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0849 - val_loss: 0.6656
# Epoch 73/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0738 - val_loss: 0.6711
# Epoch 74/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0843 - val_loss: 0.6710
# Epoch 75/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0755 - val_loss: 0.6668
# Epoch 76/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0761 - val_loss: 0.6648
# Epoch 77/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0803 - val_loss: 0.6661
# Epoch 78/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0720 - val_loss: 0.6665
# Epoch 79/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0724 - val_loss: 0.6719
# Epoch 80/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0762 - val_loss: 0.6642
# Epoch 81/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0738 - val_loss: 0.6717
# Epoch 82/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0763 - val_loss: 0.6683
# Epoch 83/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0716 - val_loss: 0.6785
# Epoch 84/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0830 - val_loss: 0.6737
# Epoch 85/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0806 - val_loss: 0.6833
# Epoch 86/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0713 - val_loss: 0.6755
# Epoch 87/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0730 - val_loss: 0.6789
# Epoch 88/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0731 - val_loss: 0.6769
# Epoch 89/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0777 - val_loss: 0.6823
# Epoch 90/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0769 - val_loss: 0.6797
# Epoch 91/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0707 - val_loss: 0.6735
# Epoch 92/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0770 - val_loss: 0.6699
# Epoch 93/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0678 - val_loss: 0.6689
# Epoch 94/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0742 - val_loss: 0.6735
# Epoch 95/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0792 - val_loss: 0.6905
# Epoch 96/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0739 - val_loss: 0.6786
# Epoch 97/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0781 - val_loss: 0.6799
# Epoch 98/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0684 - val_loss: 0.6748
# Epoch 99/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0717 - val_loss: 0.6720
# Epoch 100/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0778 - val_loss: 0.6719
# Epoch 101/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0672 - val_loss: 0.6746
# Epoch 102/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0674 - val_loss: 0.6763
# Epoch 103/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0642 - val_loss: 0.6770
# Epoch 104/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0696 - val_loss: 0.6653
# Epoch 105/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0678 - val_loss: 0.6628
# Epoch 106/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0697 - val_loss: 0.6691
# Epoch 107/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0630 - val_loss: 0.6691
# Epoch 108/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0670 - val_loss: 0.6730
# Epoch 109/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0697 - val_loss: 0.6917
# Epoch 110/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0750 - val_loss: 0.6734
# Epoch 111/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0681 - val_loss: 0.6865
# Epoch 112/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0700 - val_loss: 0.7083
# Epoch 113/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0706 - val_loss: 0.7120
# Epoch 114/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0770 - val_loss: 0.7143
# Epoch 115/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0716 - val_loss: 0.7228
# Epoch 116/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0701 - val_loss: 0.6885
# Epoch 117/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0776 - val_loss: 0.6912
# Epoch 118/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0744 - val_loss: 0.6819
# Epoch 119/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0725 - val_loss: 0.6692
# Epoch 120/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0825 - val_loss: 0.6777
# Epoch 121/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0727 - val_loss: 0.6756
# Epoch 122/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0733 - val_loss: 0.6870
# Epoch 123/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0823 - val_loss: 0.7031
# Epoch 124/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0904 - val_loss: 0.7083
# Epoch 125/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0928 - val_loss: 0.7093
# Epoch 126/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1039 - val_loss: 0.6940
# Epoch 127/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0839 - val_loss: 0.6714
# Epoch 128/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0842 - val_loss: 0.6619

# %% [markdown]
# #### <span style="font-family:Courier New; color:#994C00">**Word2Vec & FastText**</span>

# %%
cbow = fasttext.load_model('Word2Vec/dist_models/cbow_whole.bin')
fasttext = fasttext.load_model('Word2Vec/dist_models/fasttext_whole.bin')

# %%
#Map trained embedddings with input data ids
embedding_size = 100

#cbow
_pretrained_weights_cbow = np.zeros(
            (len(diccionario.token2id) + 1, embedding_size),  dtype=np.float32)
for token, _id in diccionario.token2id.items():
    if token in cbow:
        _pretrained_weights_cbow[_id + 1] = cbow[token]

#fasttext
_pretrained_weights_fasttext = np.zeros(
            (len(diccionario.token2id) + 1, embedding_size),  dtype=np.float32)
for token, _id in diccionario.token2id.items():
    if token in fasttext:
        _pretrained_weights_fasttext[_id + 1] = fasttext[token]

# %%
model_cbow = model(pretrained_weights=_pretrained_weights_cbow, trainable=True)
model_fasttext = model(pretrained_weights=_pretrained_weights_fasttext, trainable=True)
model_fasttext.summary()
# Out:
# Model: "functional_87"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_86      │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_87      │ (None, 96)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_43        │ (None, 96, 100)   │  1,312,600 │ input_layer_86[0… │
# │ (Embedding)         │                   │            │ input_layer_87[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_129 (Lambda) │ (None, 96)        │          0 │ input_layer_86[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_130 (Lambda) │ (None, 96)        │          0 │ input_layer_87[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 100)       │          0 │ embedding_43[0][… │
# │ (GlobalAveragePool… │                   │            │ lambda_129[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 100)       │          0 │ embedding_43[1][… │
# │ (GlobalAveragePool… │                   │            │ lambda_130[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_131 (Lambda) │ (None, 100)       │          0 │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_125 (Dense)   │ (None, 64)        │      6,464 │ lambda_131[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_82          │ (None, 64)        │          0 │ dense_125[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_126 (Dense)   │ (None, 128)       │      8,320 │ dropout_82[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_83          │ (None, 128)       │          0 │ dense_126[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_127 (Dense)   │ (None, 1)         │        129 │ dropout_83[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,327,513 (5.06 MB)
#  Trainable params: 1,327,513 (5.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cbow.fit(train_dataset, epochs=128, validation_data=val_dataset)
model_fasttext.fit(train_dataset, epochs=128, validation_data=val_dataset)
# Out:
# Epoch 1/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2766 - val_loss: 1.8101
# Epoch 2/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1401 - val_loss: 0.7293
# Epoch 3/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8345 - val_loss: 0.7066
# Epoch 4/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8250 - val_loss: 0.7033
# Epoch 5/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7742 - val_loss: 0.6976
# Epoch 6/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7992 - val_loss: 0.6904
# Epoch 7/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7355 - val_loss: 0.6848
# Epoch 8/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7302 - val_loss: 0.6788
# Epoch 9/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6546 - val_loss: 0.6726
# Epoch 10/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5937 - val_loss: 0.6678
# Epoch 11/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5197 - val_loss: 0.6654
# Epoch 12/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4532 - val_loss: 0.6671
# Epoch 13/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3782 - val_loss: 0.6743
# Epoch 14/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3143 - val_loss: 0.6792
# Epoch 15/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2509 - val_loss: 0.6909
# Epoch 16/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2225 - val_loss: 0.6974
# Epoch 17/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1902 - val_loss: 0.7080
# Epoch 18/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1866 - val_loss: 0.7118
# Epoch 19/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1736 - val_loss: 0.7035
# Epoch 20/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1523 - val_loss: 0.7067
# Epoch 21/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1489 - val_loss: 0.7089
# Epoch 22/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1403 - val_loss: 0.7035
# Epoch 23/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1268 - val_loss: 0.7013
# Epoch 24/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1221 - val_loss: 0.7022
# Epoch 25/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1206 - val_loss: 0.7107
# Epoch 26/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1066 - val_loss: 0.7141
# Epoch 27/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1169 - val_loss: 0.7124
# Epoch 28/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1095 - val_loss: 0.7147
# Epoch 29/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1042 - val_loss: 0.7116
# Epoch 30/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1018 - val_loss: 0.7135
# Epoch 31/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1038 - val_loss: 0.7207
# Epoch 32/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1045 - val_loss: 0.7139
# Epoch 33/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0973 - val_loss: 0.7334
# Epoch 34/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0961 - val_loss: 0.7252
# Epoch 35/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0942 - val_loss: 0.7292
# Epoch 36/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0882 - val_loss: 0.7472
# Epoch 37/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0878 - val_loss: 0.7344
# Epoch 38/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0920 - val_loss: 0.7720
# Epoch 39/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0936 - val_loss: 0.7892
# Epoch 40/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0949 - val_loss: 0.7864
# Epoch 41/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0997 - val_loss: 0.8331
# Epoch 42/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0912 - val_loss: 0.8941
# Epoch 43/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1143 - val_loss: 0.9445
# Epoch 44/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1115 - val_loss: 1.0000
# Epoch 45/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1157 - val_loss: 1.1360
# Epoch 46/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1447 - val_loss: 1.3050
# Epoch 47/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2013 - val_loss: 1.3965
# Epoch 48/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2485 - val_loss: 1.3595
# Epoch 49/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3299 - val_loss: 1.1924
# Epoch 50/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3827 - val_loss: 0.8541
# Epoch 51/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3482 - val_loss: 0.6652
# Epoch 52/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2930 - val_loss: 0.6868
# Epoch 53/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2779 - val_loss: 0.6966
# Epoch 54/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2164 - val_loss: 0.6892
# Epoch 55/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1972 - val_loss: 0.6966
# Epoch 56/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1593 - val_loss: 0.7011
# Epoch 57/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1472 - val_loss: 0.7065
# Epoch 58/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1456 - val_loss: 0.7034
# Epoch 59/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1279 - val_loss: 0.6959
# Epoch 60/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1034 - val_loss: 0.6967
# Epoch 61/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1028 - val_loss: 0.6927
# Epoch 62/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0904 - val_loss: 0.6806
# Epoch 63/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0829 - val_loss: 0.6817
# Epoch 64/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0728 - val_loss: 0.6815
# Epoch 65/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0711 - val_loss: 0.6854
# Epoch 66/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0760 - val_loss: 0.6872
# Epoch 67/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0681 - val_loss: 0.6909
# Epoch 68/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0681 - val_loss: 0.6890
# Epoch 69/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0714 - val_loss: 0.6880
# Epoch 70/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0714 - val_loss: 0.6873
# Epoch 71/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0600 - val_loss: 0.7028
# Epoch 72/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0661 - val_loss: 0.6911
# Epoch 73/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0607 - val_loss: 0.6950
# Epoch 74/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0581 - val_loss: 0.7046
# Epoch 75/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0732 - val_loss: 0.7032
# Epoch 76/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0617 - val_loss: 0.6999
# Epoch 77/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0620 - val_loss: 0.6959
# Epoch 78/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0669 - val_loss: 0.7015
# Epoch 79/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0608 - val_loss: 0.6928
# Epoch 80/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0603 - val_loss: 0.6880
# Epoch 81/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0600 - val_loss: 0.6933
# Epoch 82/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0666 - val_loss: 0.6914
# Epoch 83/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0632 - val_loss: 0.6881
# Epoch 84/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0574 - val_loss: 0.6782
# Epoch 85/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0595 - val_loss: 0.6810
# Epoch 86/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0625 - val_loss: 0.6760
# Epoch 87/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0609 - val_loss: 0.6710
# Epoch 88/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0561 - val_loss: 0.6745
# Epoch 89/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0627 - val_loss: 0.6741
# Epoch 90/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0594 - val_loss: 0.6789
# Epoch 91/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0659 - val_loss: 0.6846
# Epoch 92/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0647 - val_loss: 0.6981
# Epoch 93/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0645 - val_loss: 0.7003
# Epoch 94/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0655 - val_loss: 0.6945
# Epoch 95/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0646 - val_loss: 0.6945
# Epoch 96/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0661 - val_loss: 0.7077
# Epoch 97/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0726 - val_loss: 0.7156
# Epoch 98/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0823 - val_loss: 0.6873
# Epoch 99/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0755 - val_loss: 0.6934
# Epoch 100/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0796 - val_loss: 0.6913
# Epoch 101/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0702 - val_loss: 0.6828
# Epoch 102/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0701 - val_loss: 0.6855
# Epoch 103/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0749 - val_loss: 0.6897
# Epoch 104/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0814 - val_loss: 0.7155
# Epoch 105/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 0.7578
# Epoch 106/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0944 - val_loss: 0.7789
# Epoch 107/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1086 - val_loss: 0.8292
# Epoch 108/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1183 - val_loss: 0.8507
# Epoch 109/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1163 - val_loss: 0.8894
# Epoch 110/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1374 - val_loss: 0.8503
# Epoch 111/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1495 - val_loss: 0.8328
# Epoch 112/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1368 - val_loss: 0.7624
# Epoch 113/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1322 - val_loss: 0.7161
# Epoch 114/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1220 - val_loss: 0.6866
# Epoch 115/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1158 - val_loss: 0.6717
# Epoch 116/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1030 - val_loss: 0.6829
# Epoch 117/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1065 - val_loss: 0.7026
# Epoch 118/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0962 - val_loss: 0.7094
# Epoch 119/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0905 - val_loss: 0.7160
# Epoch 120/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0929 - val_loss: 0.7113
# Epoch 121/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0889 - val_loss: 0.6895
# Epoch 122/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0749 - val_loss: 0.6847
# Epoch 123/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0750 - val_loss: 0.6815
# Epoch 124/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0664 - val_loss: 0.6753
# Epoch 125/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0650 - val_loss: 0.6717
# Epoch 126/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0662 - val_loss: 0.6671
# Epoch 127/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0603 - val_loss: 0.6684
# Epoch 128/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0529 - val_loss: 0.6703
# Epoch 1/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4479 - val_loss: 2.5559
# Epoch 2/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5650 - val_loss: 0.7182
# Epoch 3/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8730 - val_loss: 0.7138
# Epoch 4/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8155 - val_loss: 0.7128
# Epoch 5/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8016 - val_loss: 0.7098
# Epoch 6/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8226 - val_loss: 0.7054
# Epoch 7/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7886 - val_loss: 0.7023
# Epoch 8/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7676 - val_loss: 0.6938
# Epoch 9/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6794 - val_loss: 0.6853
# Epoch 10/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6486 - val_loss: 0.6842
# Epoch 11/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5730 - val_loss: 0.6785
# Epoch 12/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4399 - val_loss: 0.6816
# Epoch 13/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3699 - val_loss: 0.6950
# Epoch 14/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2940 - val_loss: 0.7106
# Epoch 15/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2581 - val_loss: 0.7076
# Epoch 16/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2129 - val_loss: 0.7234
# Epoch 17/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1940 - val_loss: 0.7274
# Epoch 18/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1867 - val_loss: 0.7288
# Epoch 19/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1532 - val_loss: 0.7217
# Epoch 20/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1490 - val_loss: 0.7268
# Epoch 21/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1399 - val_loss: 0.7297
# Epoch 22/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1289 - val_loss: 0.7270
# Epoch 23/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1345 - val_loss: 0.7188
# Epoch 24/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1219 - val_loss: 0.7198
# Epoch 25/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1230 - val_loss: 0.7201
# Epoch 26/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1169 - val_loss: 0.7214
# Epoch 27/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1087 - val_loss: 0.7317
# Epoch 28/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1157 - val_loss: 0.7271
# Epoch 29/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1039 - val_loss: 0.7273
# Epoch 30/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1051 - val_loss: 0.7187
# Epoch 31/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0984 - val_loss: 0.7170
# Epoch 32/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0918 - val_loss: 0.7250
# Epoch 33/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0891 - val_loss: 0.7324
# Epoch 34/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0878 - val_loss: 0.7456
# Epoch 35/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0967 - val_loss: 0.7539
# Epoch 36/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0928 - val_loss: 0.7447
# Epoch 37/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0877 - val_loss: 0.7576
# Epoch 38/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0892 - val_loss: 0.7660
# Epoch 39/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0853 - val_loss: 0.7678
# Epoch 40/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0804 - val_loss: 0.7958
# Epoch 41/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0866 - val_loss: 0.8285
# Epoch 42/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0859 - val_loss: 0.9098
# Epoch 43/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1126 - val_loss: 0.9424
# Epoch 44/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1007 - val_loss: 1.0063
# Epoch 45/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1176 - val_loss: 1.0229
# Epoch 46/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1156 - val_loss: 1.0801
# Epoch 47/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1281 - val_loss: 1.1813
# Epoch 48/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1576 - val_loss: 1.2603
# Epoch 49/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2096 - val_loss: 1.1578
# Epoch 50/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2308 - val_loss: 1.1713
# Epoch 51/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3004 - val_loss: 0.8209
# Epoch 52/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3160 - val_loss: 0.6756
# Epoch 53/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3330 - val_loss: 0.7237
# Epoch 54/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2762 - val_loss: 0.7217
# Epoch 55/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2506 - val_loss: 0.7245
# Epoch 56/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2363 - val_loss: 0.7289
# Epoch 57/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1770 - val_loss: 0.7179
# Epoch 58/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1620 - val_loss: 0.7140
# Epoch 59/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1379 - val_loss: 0.7016
# Epoch 60/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1178 - val_loss: 0.6979
# Epoch 61/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1048 - val_loss: 0.6874
# Epoch 62/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0932 - val_loss: 0.6852
# Epoch 63/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0909 - val_loss: 0.6847
# Epoch 64/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0863 - val_loss: 0.6870
# Epoch 65/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0746 - val_loss: 0.6846
# Epoch 66/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0803 - val_loss: 0.6881
# Epoch 67/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0679 - val_loss: 0.6875
# Epoch 68/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0671 - val_loss: 0.6887
# Epoch 69/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0676 - val_loss: 0.6910
# Epoch 70/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0606 - val_loss: 0.6923
# Epoch 71/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0667 - val_loss: 0.6947
# Epoch 72/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0623 - val_loss: 0.7020
# Epoch 73/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0609 - val_loss: 0.7032
# Epoch 74/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0670 - val_loss: 0.7060
# Epoch 75/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0606 - val_loss: 0.7032
# Epoch 76/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0607 - val_loss: 0.7002
# Epoch 77/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0573 - val_loss: 0.6914
# Epoch 78/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0566 - val_loss: 0.6969
# Epoch 79/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0528 - val_loss: 0.6875
# Epoch 80/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0566 - val_loss: 0.6902
# Epoch 81/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0564 - val_loss: 0.6912
# Epoch 82/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0596 - val_loss: 0.6884
# Epoch 83/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0562 - val_loss: 0.6883
# Epoch 84/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0597 - val_loss: 0.6842
# Epoch 85/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0575 - val_loss: 0.6827
# Epoch 86/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0535 - val_loss: 0.6875
# Epoch 87/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0507 - val_loss: 0.6855
# Epoch 88/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0591 - val_loss: 0.6857
# Epoch 89/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0588 - val_loss: 0.6843
# Epoch 90/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0522 - val_loss: 0.6881
# Epoch 91/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0543 - val_loss: 0.6914
# Epoch 92/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0552 - val_loss: 0.6955
# Epoch 93/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0591 - val_loss: 0.6897
# Epoch 94/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0568 - val_loss: 0.6895
# Epoch 95/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0582 - val_loss: 0.6898
# Epoch 96/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0578 - val_loss: 0.6843
# Epoch 97/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0576 - val_loss: 0.6876
# Epoch 98/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0603 - val_loss: 0.6885
# Epoch 99/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0542 - val_loss: 0.6904
# Epoch 100/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0573 - val_loss: 0.6920
# Epoch 101/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0589 - val_loss: 0.6941
# Epoch 102/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0597 - val_loss: 0.6912
# Epoch 103/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0526 - val_loss: 0.6955
# Epoch 104/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0597 - val_loss: 0.7080
# Epoch 105/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0679 - val_loss: 0.7071
# Epoch 106/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0582 - val_loss: 0.7242
# Epoch 107/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0630 - val_loss: 0.7311
# Epoch 108/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0664 - val_loss: 0.7407
# Epoch 109/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0615 - val_loss: 0.7600
# Epoch 110/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0744 - val_loss: 0.7809
# Epoch 111/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0772 - val_loss: 0.7593
# Epoch 112/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0833 - val_loss: 0.7945
# Epoch 113/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0901 - val_loss: 0.7547
# Epoch 114/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0850 - val_loss: 0.7137
# Epoch 115/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0903 - val_loss: 0.6985
# Epoch 116/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0902 - val_loss: 0.6824
# Epoch 117/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0920 - val_loss: 0.6745
# Epoch 118/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1045 - val_loss: 0.7086
# Epoch 119/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1072 - val_loss: 0.7460
# Epoch 120/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1342 - val_loss: 0.8090
# Epoch 121/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1482 - val_loss: 0.8144
# Epoch 122/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1430 - val_loss: 0.7885
# Epoch 123/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1358 - val_loss: 0.7512
# Epoch 124/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1320 - val_loss: 0.7188
# Epoch 125/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1050 - val_loss: 0.6903
# Epoch 126/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0933 - val_loss: 0.6768
# Epoch 127/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0801 - val_loss: 0.6752
# Epoch 128/128
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0826 - val_loss: 0.6806

# %% [markdown]
# ### <span style="font-family:Courier New; color:#336633">**Evaluation**</span>

# %%
index = ['random', 'cbow', 'fasttext']
results_df = pd.DataFrame(index=index, columns=['cf Pearson (train)', 'cf Pearson (val)', 'cf Pearson (test)'])

x_test, y_test = pair_list_to_x_y(mapped_test)
def compute_pearson(x_, y_, model):
    
    # Get predictions for the model
    y_pred = model.predict(x_)
    # Compute pearson correlation
    correlation, _ = pearsonr(y_pred.flatten(), y_.flatten())
    return correlation

# %%
models = [model_random, model_cbow, model_fasttext]
for i, model in enumerate(index):
    results_df.loc[model, 'cf Pearson (train)'] = compute_pearson(x_train, y_train, models[i])
    results_df.loc[model, 'cf Pearson (val)'] = compute_pearson(x_val, y_val, models[i])
    results_df.loc[model, 'cf Pearson (test)'] = compute_pearson(x_test, y_test, models[i])
results_df
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#          cf Pearson (train) cf Pearson (val) cf Pearson (test)
# random             0.982905         0.302388          0.391531
# cbow               0.989596         0.306419          0.339157
# fasttext           0.985586         0.281861          0.315383
